# %%
# %cd homework4
# Out:
# [Errno 2] No such file or directory: 'homework4'
# /workspace/deep-learning/homework4

# %% [markdown]
# # Colab T4 + drive
# # !python3 -m homework.train --log_dir log --batch_size 512 --epochs 60 --patience 60
# CUDA Memory used beginning of epoch: 2855936
# CUDA Memory used after train: 288151552 | Time 92.03s
# Epoch 1/60 | Train Loss: 13.475167512893677 | LR: 0.001 | Valid Accuracy: 0.09921635687351227 | Time 358.99s
# CUDA Memory used beginning of epoch: 288552448
# CUDA Memory used after train: 288552448 | Time 87.12s
#
# # Colab T4
# CUDA Memory used after train: 288151552 | Time 77.36s
# Epoch 1/60 | Train Loss: 12.427887380123138 | LR: 0.001 | Valid Accuracy: 0.09006468206644058 | Time 339.86s
# CUDA Memory used beginning of epoch: 288552448
# CUDA Memory used after train: 288552448 | Time 75.20s
# Epoch 2/60 | Train Loss: 12.409678936004639 | LR: 0.001 | Valid Accuracy: 0.039607934653759 | Time 336.93s
#
# # Colab T100
# CUDA Memory used beginning of epoch: 2855936
# CUDA Memory used after train: 288151552 | Time 70.29s
# Epoch 1/60 | Train Loss: 15.249160945415497 | LR: 0.001 | Valid Accuracy: 0.03147116303443909 | Time 357.45s

# %%
import homework.utils
import runpy
runpy.run_module("homework.utils", run_name= "__main__")
# Out:
# /home/gitpod/.pyenv/versions/3.8.18/lib/python3.8/runpy.py:127: RuntimeWarning: 'homework.utils' found in sys.modules after import of package 'homework', but prior to execution of 'homework.utils'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# {'__name__': '__main__',
#  '__file__': '/workspace/deep-learning/homework4/homework/utils.py',
#  '__cached__': '/workspace/deep-learning/homework4/homework/__pycache__/utils.cpython-38.pyc',
#  '__doc__': None,
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f0d1431e610>,
#  '__package__': 'homework',
#  '__spec__': ModuleSpec(name='homework.utils', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f0d1431e610>, origin='/workspace/deep-learning/homework4/homework/utils.py'),
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
# ...
